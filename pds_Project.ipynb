# %% [markdown]
# # 1. Importing libraries and Dataset

# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("Skyserver_SQL2_27_2018 6_51_39 PM.csv")

# %%
data.head()
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598370  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
# 3  1.237650e+18  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233
# 4  1.237650e+18  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492
#
#           z  run  rerun  camcol  field     specobjid   class  redshift  plate  \
# 0  15.22531  752    301       4    267  3.722360e+18    STAR -0.000009   3306
# 1  16.39150  752    301       4    267  3.638140e+17    STAR -0.000055    323
# 2  16.80125  752    301       4    268  3.232740e+17  GALAXY  0.123111    287
# 3  15.90438  752    301       4    269  3.722370e+18    STAR -0.000111   3306
# 4  16.61326  752    301       4    269  3.722370e+18    STAR  0.000590   3306
#
#      mjd  fiberid
# 0  54922      491
# 1  51615      541
# 2  52023      513
# 3  54922      510
# 4  54922      512

# %% [markdown]
# # 2. Knowing about the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   objid      10000 non-null  float64
#  1   ra         10000 non-null  float64
#  2   dec        10000 non-null  float64
#  3   u          10000 non-null  float64
#  4   g          10000 non-null  float64
#  5   r          10000 non-null  float64
#  6   i          10000 non-null  float64
#  7   z          10000 non-null  float64
#  8   run        10000 non-null  int64
#  9   rerun      10000 non-null  int64
#  10  camcol     10000 non-null  int64
#  11  field      10000 non-null  int64
#  12  specobjid  10000 non-null  float64
#  13  class      10000 non-null  object
#  14  redshift   10000 non-null  float64
#  15  plate      10000 non-null  int64
#  16  mjd        10000 non-null  int64
#  17  fiberid    10000 non-null  int64
# dtypes: float64(10), int64(7), object(1)
# memory usage: 1.4+ MB

# %%
data.describe()
# Out:
#               objid            ra           dec             u             g  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000  10000.000000
# mean   1.237650e+18    175.529987     14.836148     18.619355     17.371931
# std    0.000000e+00     47.783439     25.212207      0.828656      0.945457
# min    1.237650e+18      8.235100     -5.382632     12.988970     12.799550
# 25%    1.237650e+18    157.370946     -0.539035     18.178035     16.815100
# 50%    1.237650e+18    180.394514      0.404166     18.853095     17.495135
# 75%    1.237650e+18    201.547279     35.649397     19.259232     18.010145
# max    1.237650e+18    260.884382     68.542265     19.599900     19.918970
#
#                   r             i             z           run    rerun  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.0
# mean      16.840963     16.583579     16.422833    981.034800    301.0
# std        1.067764      1.141805      1.203188    273.305024      0.0
# min       12.431600     11.947210     11.610410    308.000000    301.0
# 25%       16.173333     15.853705     15.618285    752.000000    301.0
# 50%       16.858770     16.554985     16.389945    756.000000    301.0
# 75%       17.512675     17.258550     17.141447   1331.000000    301.0
# max       24.802040     28.179630     22.833060   1412.000000    301.0
#
#              camcol         field     specobjid      redshift         plate  \
# count  10000.000000  10000.000000  1.000000e+04  10000.000000  10000.000000
# mean       3.648700    302.380100  1.645022e+18      0.143726   1460.986400
# std        1.666183    162.577763  2.013998e+18      0.388774   1788.778371
# min        1.000000     11.000000  2.995780e+17     -0.004136    266.000000
# 25%        2.000000    184.000000  3.389248e+17      0.000081    301.000000
# 50%        4.000000    299.000000  4.966580e+17      0.042591    441.000000
# 75%        5.000000    414.000000  2.881300e+18      0.092579   2559.000000
# max        6.000000    768.000000  9.468830e+18      5.353854   8410.000000
#
#                 mjd       fiberid
# count  10000.000000  10000.000000
# mean   52943.533300    353.069400
# std     1511.150651    206.298149
# min    51578.000000      1.000000
# 25%    51900.000000    186.750000
# 50%    51997.000000    351.000000
# 75%    54468.000000    510.000000
# max    57481.000000   1000.000000

# %%
data['class'].value_counts()
# Out:
# GALAXY    4998
# STAR      4152
# QSO        850
# Name: class, dtype: int64

# %%
data['class'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# objid        0
# ra           0
# dec          0
# u            0
# g            0
# r            0
# i            0
# z            0
# run          0
# rerun        0
# camcol       0
# field        0
# specobjid    0
# class        0
# redshift     0
# plate        0
# mjd          0
# fiberid      0
# dtype: int64

# %%
data.corr()
# Out:
#            objid        ra       dec         u         g         r         i  \
# objid        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ra           NaN  1.000000  0.003596  0.031238  0.043909  0.047103  0.045731
# dec          NaN  0.003596  1.000000  0.035279  0.061875  0.063404  0.058292
# u            NaN  0.031238  0.035279  1.000000  0.849232  0.692379  0.602630
# g            NaN  0.043909  0.061875  0.849232  1.000000  0.958106  0.907419
# r            NaN  0.047103  0.063404  0.692379  0.958106  1.000000  0.977672
# i            NaN  0.045731  0.058292  0.602630  0.907419  0.977672  1.000000
# z            NaN  0.042950  0.056870  0.551483  0.879622  0.969197  0.981507
# run          NaN -0.092741  0.778385  0.038229  0.058446  0.057261  0.049765
# rerun        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# camcol       NaN -0.006294  0.114614  0.009945  0.010223  0.010747  0.013461
# field        NaN  0.594700 -0.131471  0.008548  0.014651  0.017133  0.019781
# specobjid    NaN -0.095327  0.088345 -0.129429 -0.054979  0.019788  0.072960
# redshift     NaN  0.030307  0.067021  0.163741  0.407576  0.441080  0.431450
# plate        NaN -0.095329  0.088342 -0.129430 -0.054981  0.019787  0.072958
# mjd          NaN -0.086887  0.066147 -0.168793 -0.092772 -0.009345  0.050896
# fiberid      NaN  0.057485  0.155012  0.011301  0.047187  0.061081  0.069977
#
#                   z       run  rerun    camcol     field  specobjid  redshift  \
# objid           NaN       NaN    NaN       NaN       NaN        NaN       NaN
# ra         0.042950 -0.092741    NaN -0.006294  0.594700  -0.095327  0.030307
# dec        0.056870  0.778385    NaN  0.114614 -0.131471   0.088345  0.067021
# u          0.551483  0.038229    NaN  0.009945  0.008548  -0.129429  0.163741
# g          0.879622  0.058446    NaN  0.010223  0.014651  -0.054979  0.407576
# r          0.969197  0.057261    NaN  0.010747  0.017133   0.019788  0.441080
# i          0.981507  0.049765    NaN  0.013461  0.019781   0.072960  0.431450
# z          1.000000  0.048252    NaN  0.010930  0.018248   0.112398  0.424034
# run        0.048252  1.000000    NaN  0.151814 -0.463898   0.093604  0.059056
# rerun           NaN       NaN    NaN       NaN       NaN        NaN       NaN
# camcol     0.010930  0.151814    NaN  1.000000 -0.067921   0.040809  0.006834
# field      0.018248 -0.463898    NaN -0.067921  1.000000  -0.093724  0.015414
# specobjid  0.112398  0.093604    NaN  0.040809 -0.093724   1.000000 -0.038090
# redshift   0.424034  0.059056    NaN  0.006834  0.015414  -0.038090  1.000000
# plate      0.112397  0.093601    NaN  0.040795 -0.093723   1.000000 -0.038091
# mjd        0.095658  0.070354    NaN  0.026284 -0.086558   0.966880 -0.057957
# fiberid    0.067980  0.138566    NaN  0.535629 -0.040493   0.229837  0.046532
#
#               plate       mjd   fiberid
# objid           NaN       NaN       NaN
# ra        -0.095329 -0.086887  0.057485
# dec        0.088342  0.066147  0.155012
# u         -0.129430 -0.168793  0.011301
# g         -0.054981 -0.092772  0.047187
# r          0.019787 -0.009345  0.061081
# i          0.072958  0.050896  0.069977
# z          0.112397  0.095658  0.067980
# run        0.093601  0.070354  0.138566
# rerun           NaN       NaN       NaN
# camcol     0.040795  0.026284  0.535629
# field     -0.093723 -0.086558 -0.040493
# specobjid  1.000000  0.966880  0.229837
# redshift  -0.038091 -0.057957  0.046532
# plate      1.000000  0.966881  0.229811
# mjd        0.966881  1.000000  0.190328
# fiberid    0.229811  0.190328  1.000000

# %%
data.columns.values
# Out:
# array(['objid', 'ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'rerun',
#        'camcol', 'field', 'specobjid', 'class', 'redshift', 'plate',
#        'mjd', 'fiberid'], dtype=object)

# %% [markdown]
# # 3. Data Pre-processing

# %%
data.drop(['objid','camcol','field','specobjid','rerun','run'],axis=1,inplace=True)
data.head()
# Out:
#            ra       dec         u         g         r         i         z  \
# 0  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342  15.22531
# 1  183.598370  0.135285  18.66280  17.21449  16.67637  16.48922  16.39150
# 2  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732  16.80125
# 3  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233  15.90438
# 4  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492  16.61326
#
#     class  redshift  plate    mjd  fiberid
# 0    STAR -0.000009   3306  54922      491
# 1    STAR -0.000055    323  51615      541
# 2  GALAXY  0.123111    287  52023      513
# 3    STAR -0.000111   3306  54922      510
# 4    STAR  0.000590   3306  54922      512

# %% [markdown]
# # 4. EDA

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(nrows=1, ncols=3,figsize=(16, 4))
fig.set_dpi(100)
ax = sns.heatmap(data[data['class']=='STAR'][['u', 'g', 'r', 'i', 'z']].corr(), ax = axes[0], cmap='coolwarm')
ax.set_title('Star')
ax = sns.heatmap(data[data['class']=='GALAXY'][['u', 'g', 'r', 'i', 'z']].corr(), ax = axes[1], cmap='coolwarm')
ax.set_title('Galaxy')
ax = sns.heatmap(data[data['class']=='QSO'][['u', 'g', 'r', 'i', 'z']].corr(), ax = axes[2], cmap='coolwarm')
ax = ax.set_title('QSO')

# %%
plt.figure(figsize = (17, 10))
ax=plt.subplot(2,6,1)
sns.boxplot(x = data['class'],y =data['ra'])
ax.set_title('ra')
ax=plt.subplot(2,6,2)
sns.boxplot(x = data['class'],y =data['dec'])
ax.set_title('dec')
ax=plt.subplot(2,6,3)
sns.boxplot(x = data['class'],y =data['u'])
ax.set_title('u')
ax=plt.subplot(2,6,4)
sns.boxplot(x = data['class'],y =data['r'])
ax.set_title('r')
ax=plt.subplot(2,6,5)
sns.boxplot(x = data['class'],y =data['i'])
ax.set_title('i')
ax=plt.subplot(2,6,6)
sns.boxplot(x = data['class'],y =data['redshift'])
ax.set_title('redshift')
ax=plt.subplot(2,6,7)
sns.boxplot(x = data['class'],y =data['plate'])
ax.set_title('plate')
ax=plt.subplot(2,6,8)
sns.boxplot(x = data['class'],y =data['mjd'])
ax.set_title('mjd')
ax=plt.subplot(2,6,9)
sns.boxplot(x = data['class'],y = data['fiberid'])
ax.set_title('fiberid')
ax=plt.subplot(2,6,10)
sns.boxplot(x = data['class'],y =data['z'])
ax=plt.subplot(2,6,11)
sns.boxplot(x = data['class'],y =data['g'])
# Out:
# <AxesSubplot:xlabel='class', ylabel='g'>

# %%
sns.pairplot(data)

# %% [markdown]
# # 5. Outliners Removal

# %%
#remove Outliers
def outliers(df,ft):
    Q1 = df[ft].quantile(0.25)
    Q3 = df[ft].quantile(0.75)
    IQR = Q3-Q1
    
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    ls = df.index[ (df[ft] < lower_bound) | (df[ft] > upper_bound)]
    
    return ls


index_list = []
for feature in ['ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'plate','mjd', 'fiberid']:
    index_list.extend(outliers(data,feature))
    
def remove(df,ls):
    ls = sorted(set(ls))
    df =df.drop(ls)
    return df

# %%
data_cleaned = remove(data,index_list)

# %%
data_cleaned.shape
# Out:
# (8693, 12)

# %%
data.shape
# Out:
# (10000, 12)

# %%
plt.figure(figsize = (17, 10))
ax=plt.subplot(2,6,1)
sns.boxplot(x = data_cleaned['class'],y =data['ra'])
ax.set_title('ra')
ax=plt.subplot(2,6,2)
sns.boxplot(x = data_cleaned['class'],y =data['dec'])
ax.set_title('dec')
ax=plt.subplot(2,6,3)
sns.boxplot(x = data_cleaned['class'],y =data['u'])
ax.set_title('u')
ax=plt.subplot(2,6,4)
sns.boxplot(x = data_cleaned['class'],y =data['r'])
ax.set_title('r')
ax=plt.subplot(2,6,5)
sns.boxplot(x = data_cleaned['class'],y =data['i'])
ax.set_title('i')
ax=plt.subplot(2,6,6)
sns.boxplot(x = data_cleaned['class'],y =data['redshift'])
ax.set_title('redshift')
ax=plt.subplot(2,6,7)
sns.boxplot(x = data_cleaned['class'],y =data['plate'])
ax.set_title('plate')
ax=plt.subplot(2,6,8)
sns.boxplot(x = data_cleaned['class'],y =data['mjd'])
ax.set_title('mjd')
ax=plt.subplot(2,6,9)
sns.boxplot(x = data_cleaned['class'],y = data['fiberid'])
ax.set_title('fiberid')
ax=plt.subplot(2,6,10)
sns.boxplot(x = data_cleaned['class'],y =data['z'])
ax=plt.subplot(2,6,11)
sns.boxplot(x = data_cleaned['class'],y =data['g'])
# Out:
# <AxesSubplot:xlabel='class', ylabel='g'>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder = LabelEncoder()
data_cleaned['class'] = labelencoder.fit_transform(data_cleaned['class'])
data_cleaned.head()
# Out:
#            ra       dec         u         g         r         i         z  \
# 0  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342  15.22531
# 1  183.598370  0.135285  18.66280  17.21449  16.67637  16.48922  16.39150
# 2  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732  16.80125
# 3  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233  15.90438
# 4  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492  16.61326
#
#    class  redshift  plate    mjd  fiberid
# 0      2 -0.000009   3306  54922      491
# 1      2 -0.000055    323  51615      541
# 2      0  0.123111    287  52023      513
# 3      2 -0.000111   3306  54922      510
# 4      2  0.000590   3306  54922      512

# %% [markdown]
# # -----------------------------------

# %%
data_cleaned['redshift'].describe() #Hypothesis testing
# Out:
# count    8693.000000
# mean        0.143866
# std         0.375930
# min        -0.004136
# 25%         0.000141
# 50%         0.050446
# 75%         0.095278
# max         5.353854
# Name: redshift, dtype: float64

# %% [markdown]
# # ------------------------------------------

# %%
data_cleaned['class'].value_counts()
# Out:
# 0    4679
# 2    3287
# 1     727
# Name: class, dtype: int64

# %%
data_cleaned.corrwith(data_cleaned['class'],axis=0)
# Out:
# ra         -0.001130
# dec        -0.074572
# u          -0.279941
# g          -0.091705
# r           0.066195
# i           0.167219
# z           0.239449
# class       1.000000
# redshift   -0.058546
# plate       0.675018
# mjd         0.674731
# fiberid     0.001559
# dtype: float64

# %%
sns.heatmap(data_cleaned.corr())
# Out:
# <AxesSubplot:>

# %%
X = data_cleaned.drop('class',axis=1) 
y = data_cleaned['class']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,train_size=0.2,random_state=1)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %% [markdown]
# # 5.1 SVM

# %%
from sklearn.svm import SVC
svm = SVC(kernel='linear')
svm.fit(X_train, y_train)
y_pred = svm.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,precision_score,recall_score,f1_score,accuracy_score,classification_report
cm = confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[3683    9   77]
#  [  28  547    0]
#  [  24    3 2584]]

# %%
cr = classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      3769
#            1       0.98      0.95      0.96       575
#            2       0.97      0.99      0.98      2611
#
#     accuracy                           0.98      6955
#    macro avg       0.98      0.97      0.98      6955
# weighted avg       0.98      0.98      0.98      6955

# %%
print("Accuracy score: ",accuracy_score(y_test,y_pred))
# Out:
# Accuracy score:  0.9797268152408339

# %% [markdown]
# # 5.2 Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train, y_train)
y_pred1 =  nb.predict(X_test)

# %%
print("Accuracy score: ",accuracy_score(y_test,y_pred1))
# Out:
# Accuracy score:  0.9667864845434939

# %%
cm1 = confusion_matrix(y_test,y_pred1)
cm1
# Out:
# array([[3657,  101,   11],
#        [  36,  539,    0],
#        [  42,   41, 2528]], dtype=int64)

# %%
cr1 = classification_report(y_test,y_pred1)
print(cr1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97      3769
#            1       0.79      0.94      0.86       575
#            2       1.00      0.97      0.98      2611
#
#     accuracy                           0.97      6955
#    macro avg       0.92      0.96      0.94      6955
# weighted avg       0.97      0.97      0.97      6955

# %% [markdown]
# # 5.3 Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
rf.fit(X_train, y_train)
y_pred2=rf.predict(X_test)

# %%
print("Accuracy score: ",accuracy_score(y_test,y_pred2))
# Out:
# Accuracy score:  0.987922358015816

# %%
cm2 = confusion_matrix(y_test,y_pred2)
cm2
# Out:
# array([[3741,   14,   14],
#        [  50,  525,    0],
#        [   6,    0, 2605]], dtype=int64)

# %%
cr2 = classification_report(y_test,y_pred2)
print(cr2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      3769
#            1       0.97      0.91      0.94       575
#            2       0.99      1.00      1.00      2611
#
#     accuracy                           0.99      6955
#    macro avg       0.98      0.97      0.98      6955
# weighted avg       0.99      0.99      0.99      6955

# %% [markdown]
# # 5.4 KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,y_train)
y_pred3 = knn.predict(X_test)

# %%
print("Accuracy score: ",accuracy_score(y_test,y_pred3))
# Out:
# Accuracy score:  0.8969086987778576

# %%
cm3 = confusion_matrix(y_test,y_pred3)
print(cm3)
# Out:
# [[3559    9  201]
#  [  59  497   19]
#  [ 428    1 2182]]

# %%
cr3 = classification_report(y_test,y_pred3)
print(cr3)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      3769
#            1       0.98      0.86      0.92       575
#            2       0.91      0.84      0.87      2611
#
#     accuracy                           0.90      6955
#    macro avg       0.92      0.88      0.90      6955
# weighted avg       0.90      0.90      0.90      6955

# %% [markdown]
# # 6. OverSampling

# %%
from imblearn.over_sampling import SMOTE
over_sampler = SMOTE(sampling_strategy="minority")
X_oversampled, Y_oversampled = over_sampler.fit_resample(X_train, y_train)

# %%
Y_oversampled.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 6.1 SVM

# %%
svm = SVC(kernel="rbf")
svm.fit(X_oversampled, Y_oversampled)
y_pred_os = svm.predict(X_test)

# %%
cm_os = confusion_matrix(y_test,y_pred_os)
print(cm_os)
# Out:
# [[3603   17  149]
#  [  24  549    2]
#  [ 286    3 2322]]

# %%
cr_os = classification_report(y_test,y_pred_os)
print(cr_os)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      3769
#            1       0.96      0.95      0.96       575
#            2       0.94      0.89      0.91      2611
#
#     accuracy                           0.93      6955
#    macro avg       0.94      0.93      0.94      6955
# weighted avg       0.93      0.93      0.93      6955

# %%
print("Accuracy score: ",accuracy_score(y_test,y_pred_os))
# Out:
# Accuracy score:  0.930841121495327

# %% [markdown]
# # 6.2 Naive Bayes

# %%
nb = GaussianNB()
nb.fit(X_oversampled, Y_oversampled)
y_pred1_os =  nb.predict(X_test)

# %%
print("Accuracy score: ",accuracy_score(y_test,y_pred1_os))
# Out:
# Accuracy score:  0.9614665708123652

# %%
cm1_os = confusion_matrix(y_test,y_pred1_os)
cm1_os
# Out:
# array([[3651,  107,   11],
#        [  31,  544,    0],
#        [  42,   77, 2492]], dtype=int64)

# %%
cr1_os = classification_report(y_test,y_pred1_os)
print(cr1_os)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97      3769
#            1       0.75      0.95      0.83       575
#            2       1.00      0.95      0.97      2611
#
#     accuracy                           0.96      6955
#    macro avg       0.91      0.96      0.93      6955
# weighted avg       0.97      0.96      0.96      6955

# %% [markdown]
# # 6.3 Random Forest

# %%
rf_os = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
rf_os.fit(X_oversampled, Y_oversampled)
y_pred2_os=rf_os.predict(X_test)

# %%
print("Accuracy score: ",accuracy_score(y_test,y_pred2_os))
# Out:
# Accuracy score:  0.988353702372394

# %%
cm2_os = confusion_matrix(y_test,y_pred2_os)
print(cm2_os)
# Out:
# [[3727   29   13]
#  [  35  540    0]
#  [   4    0 2607]]

# %%
cr2_os = classification_report(y_test,y_pred2_os)
print(cr2_os)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      3769
#            1       0.95      0.94      0.94       575
#            2       1.00      1.00      1.00      2611
#
#     accuracy                           0.99      6955
#    macro avg       0.98      0.98      0.98      6955
# weighted avg       0.99      0.99      0.99      6955

# %% [markdown]
# # 6.4 KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_os=KNeighborsClassifier(n_neighbors=5)
knn_os.fit(X_oversampled, Y_oversampled)
y_pred3_os = knn.predict(X_test)
print("Accuracy score: ",accuracy_score(y_test,y_pred3_os))
# Out:
# Accuracy score:  0.8969086987778576

# %%
cm3_os = confusion_matrix(y_test,y_pred3_os)
print(cm3_os)
cr3_os = classification_report(y_test,y_pred3_os)
print(cr3_os)
# Out:
# [[3559    9  201]
#  [  59  497   19]
#  [ 428    1 2182]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      3769
#            1       0.98      0.86      0.92       575
#            2       0.91      0.84      0.87      2611
#
#     accuracy                           0.90      6955
#    macro avg       0.92      0.88      0.90      6955
# weighted avg       0.90      0.90      0.90      6955

# %% [markdown]
# # 7. Under Sampling

# %%
from imblearn.under_sampling import RandomUnderSampler,TomekLinks

# %%
under_sampler = RandomUnderSampler(sampling_strategy="majority")
X_undersampled, Y_undersampled = under_sampler.fit_resample(X_train,y_train)

# %%
Y_undersampled.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 7.1 SVM

# %%
svm_us = SVC(kernel="linear")
svm_us.fit(X_undersampled, Y_undersampled)
y_pred_us = svm.predict(X_test)
print("Accuracy score: ",accuracy_score(y_test,y_pred_us))
# Out:
# Accuracy score:  0.930841121495327

# %%
cm_us = confusion_matrix(y_test,y_pred_us)
print(cm_us)
# Out:
# [[3603   17  149]
#  [  24  549    2]
#  [ 286    3 2322]]

# %%
cr_us = classification_report(y_test,y_pred_us)
print(cr_us)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      3769
#            1       0.96      0.95      0.96       575
#            2       0.94      0.89      0.91      2611
#
#     accuracy                           0.93      6955
#    macro avg       0.94      0.93      0.94      6955
# weighted avg       0.93      0.93      0.93      6955

# %% [markdown]
# # 7.2 Naive Bayes

# %%
nb_us = GaussianNB()
nb_us.fit(X_undersampled, Y_undersampled)
y_pred1_us =  nb_us.predict(X_test)
print("Accuracy score: ",accuracy_score(y_test,y_pred1_us))
# Out:
# Accuracy score:  0.9669302659956865

# %%
cm1_us = confusion_matrix(y_test,y_pred1_us)
cm1_us
# Out:
# array([[3618,  139,   12],
#        [  28,  547,    0],
#        [   9,   42, 2560]], dtype=int64)

# %%
cr1_us = classification_report(y_test,y_pred1_us)
print(cr1_us)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97      3769
#            1       0.75      0.95      0.84       575
#            2       1.00      0.98      0.99      2611
#
#     accuracy                           0.97      6955
#    macro avg       0.91      0.96      0.93      6955
# weighted avg       0.97      0.97      0.97      6955

# %% [markdown]
# # 7.3 Random Forest

# %%
rf_us = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
rf_us.fit(X_undersampled, Y_undersampled)
y_pred2_us=rf_us.predict(X_test)
print("Accuracy score: ",accuracy_score(y_test,y_pred2_us))
# Out:
# Accuracy score:  0.9752695902228613

# %%
cm2_us = confusion_matrix(y_test,y_pred2_us)
print(cm2_us)
# Out:
# [[3628   73   68]
#  [  31  544    0]
#  [   0    0 2611]]

# %%
cr2_us = classification_report(y_test,y_pred2_us)
print(cr2_us)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.98      3769
#            1       0.88      0.95      0.91       575
#            2       0.97      1.00      0.99      2611
#
#     accuracy                           0.98      6955
#    macro avg       0.95      0.97      0.96      6955
# weighted avg       0.98      0.98      0.98      6955

# %% [markdown]
# # 7.4 KNN

# %%
knn_us=KNeighborsClassifier(n_neighbors=5)
knn_us.fit(X_undersampled, Y_undersampled)
y_pred3_us = knn.predict(X_test)
print("Accuracy score: ",accuracy_score(y_test,y_pred3_us))
# Out:
# Accuracy score:  0.8969086987778576

# %%
cm3_us = confusion_matrix(y_test,y_pred3_us)
print(cm3_us)
# Out:
# [[3559    9  201]
#  [  59  497   19]
#  [ 428    1 2182]]

# %%
cr3_us = classification_report(y_test,y_pred3_us)
print(cr3_us)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      3769
#            1       0.98      0.86      0.92       575
#            2       0.91      0.84      0.87      2611
#
#     accuracy                           0.90      6955
#    macro avg       0.92      0.88      0.90      6955
# weighted avg       0.90      0.90      0.90      6955

# %% [markdown]
# # 8. Final Analysis

# %%
from sklearn import metrics

# %%
Evaluation=pd.DataFrame(['SVM'],columns=['Algorithm'])
Evaluation.loc[0,'Precision']=metrics.precision_score(y_test, y_pred, average='micro')
Evaluation.loc[0,'Recall']=metrics.recall_score(y_test, y_pred, average='micro')
Evaluation.loc[0,'F1 Score']=metrics.f1_score(y_test, y_pred, average='micro')
Evaluation.loc[0,'Accuracy']=metrics.accuracy_score(y_test,y_pred)
Evaluation.loc[1,'Algorithm']='Naive_Bayes'
Evaluation.loc[1,'Precision']=metrics.precision_score(y_test, y_pred1, average='micro')
Evaluation.loc[1,'Recall']=metrics.recall_score(y_test, y_pred1, average='micro')
Evaluation.loc[1,'F1 Score']=metrics.f1_score(y_test, y_pred1, average='micro')
Evaluation.loc[1,'Accuracy']=metrics.accuracy_score(y_test,y_pred1)
Evaluation.loc[2,'Algorithm']='Random Forest'
Evaluation.loc[2,'Precision']=metrics.precision_score(y_test, y_pred2, average='micro')
Evaluation.loc[2,'Recall']=metrics.recall_score(y_test, y_pred2, average='micro')
Evaluation.loc[2,'F1 Score']=metrics.f1_score(y_test, y_pred2, average='micro')
Evaluation.loc[2,'Accuracy']=metrics.accuracy_score(y_test,y_pred2)
Evaluation.loc[3,'Algorithm']='KNN'
Evaluation.loc[3,'Precision']=metrics.precision_score(y_test, y_pred3, average='micro')
Evaluation.loc[3,'Recall']=metrics.recall_score(y_test, y_pred3, average='micro')
Evaluation.loc[3,'F1 Score']=metrics.f1_score(y_test, y_pred3, average='micro')
Evaluation.loc[3,'Accuracy']=metrics.accuracy_score(y_test,y_pred3)
display(Evaluation.loc[:].style.highlight_max(subset=['Precision', 'Accuracy','Recall','F1 Score'], color='green'))
# Out:
# <style type="text/css">
# #T_562eb_row2_col1, #T_562eb_row2_col2, #T_562eb_row2_col3, #T_562eb_row2_col4 {
#   background-color: green;
# }
# </style>
# <table id="T_562eb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_562eb_level0_col0" class="col_heading level0 col0" >Algorithm</th>
#       <th id="T_562eb_level0_col1" class="col_heading level0 col1" >Precision</th>
#       <th id="T_562eb_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_562eb_level0_col3" class="col_heading level0 col3" >F1 Score</th>
#       <th id="T_562eb_level0_col4" class="col_heading level0 col4" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_562eb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_562eb_row0_col0" class="data row0 col0" >SVM</td>
#       <td id="T_562eb_row0_col1" class="data row0 col1" >0.979727</td>
#       <td id="T_562eb_row0_col2" class="data row0 col2" >0.979727</td>
#       <td id="T_562eb_row0_col3" class="data row0 col3" >0.979727</td>
#       <td id="T_562eb_row0_col4" class="data row0 col4" >0.979727</td>
#     </tr>
#     <tr>
#       <th id="T_562eb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_562eb_row1_col0" class="data row1 col0" >Naive_Bayes</td>
#       <td id="T_562eb_row1_col1" class="data row1 col1" >0.966786</td>
#       <td id="T_562eb_row1_col2" class="data row1 col2" >0.966786</td>
#       <td id="T_562eb_row1_col3" class="data row1 col3" >0.966786</td>
#       <td id="T_562eb_row1_col4" class="data row1 col4" >0.966786</td>
#     </tr>
#     <tr>
#       <th id="T_562eb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_562eb_row2_col0" class="data row2 col0" >Random Forest</td>
#       <td id="T_562eb_row2_col1" class="data row2 col1" >0.987922</td>
#       <td id="T_562eb_row2_col2" class="data row2 col2" >0.987922</td>
#       <td id="T_562eb_row2_col3" class="data row2 col3" >0.987922</td>
#       <td id="T_562eb_row2_col4" class="data row2 col4" >0.987922</td>
#     </tr>
#     <tr>
#       <th id="T_562eb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_562eb_row3_col0" class="data row3 col0" >KNN</td>
#       <td id="T_562eb_row3_col1" class="data row3 col1" >0.896909</td>
#       <td id="T_562eb_row3_col2" class="data row3 col2" >0.896909</td>
#       <td id="T_562eb_row3_col3" class="data row3 col3" >0.896909</td>
#       <td id="T_562eb_row3_col4" class="data row3 col4" >0.896909</td>
#     </tr>
#   </tbody>
# </table>

# %%
Evaluation1=pd.DataFrame(['SVM'],columns=['Algorithm'])
Evaluation1.loc[0,'Precision']=metrics.precision_score(y_test, y_pred_os, average='micro')
Evaluation1.loc[0,'Recall']=metrics.recall_score(y_test, y_pred_os, average='micro')
Evaluation1.loc[0,'F1 Score']=metrics.f1_score(y_test, y_pred_os, average='micro')
Evaluation1.loc[0,'Accuracy']=metrics.accuracy_score(y_test,y_pred_os)
Evaluation1.loc[1,'Algorithm']='Naive_Bayes'
Evaluation1.loc[1,'Precision']=metrics.precision_score(y_test, y_pred1_os, average='micro')
Evaluation1.loc[1,'Recall']=metrics.recall_score(y_test, y_pred1_os, average='micro')
Evaluation1.loc[1,'F1 Score']=metrics.f1_score(y_test, y_pred1_os, average='micro')
Evaluation1.loc[1,'Accuracy']=metrics.accuracy_score(y_test,y_pred1_os)
Evaluation1.loc[2,'Algorithm']='Random Forest'
Evaluation1.loc[2,'Precision']=metrics.precision_score(y_test, y_pred2_os, average='micro')
Evaluation1.loc[2,'Recall']=metrics.recall_score(y_test, y_pred2_os, average='micro')
Evaluation1.loc[2,'F1 Score']=metrics.f1_score(y_test, y_pred2_os, average='micro')
Evaluation1.loc[2,'Accuracy']=metrics.accuracy_score(y_test,y_pred2_os)
Evaluation1.loc[3,'Algorithm']='KNN'
Evaluation1.loc[3,'Precision']=metrics.precision_score(y_test, y_pred3_os, average='micro')
Evaluation1.loc[3,'Recall']=metrics.recall_score(y_test, y_pred3_os, average='micro')
Evaluation1.loc[3,'F1 Score']=metrics.f1_score(y_test, y_pred3_os, average='micro')
Evaluation1.loc[3,'Accuracy']=metrics.accuracy_score(y_test,y_pred3_os)
print("OverSampling")
display(Evaluation1.loc[:].style.highlight_max(subset=['Precision', 'Accuracy','Recall','F1 Score'], color='green'))
# Out:
# OverSampling
# <style type="text/css">
# #T_9e18c_row2_col1, #T_9e18c_row2_col2, #T_9e18c_row2_col3, #T_9e18c_row2_col4 {
#   background-color: green;
# }
# </style>
# <table id="T_9e18c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e18c_level0_col0" class="col_heading level0 col0" >Algorithm</th>
#       <th id="T_9e18c_level0_col1" class="col_heading level0 col1" >Precision</th>
#       <th id="T_9e18c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_9e18c_level0_col3" class="col_heading level0 col3" >F1 Score</th>
#       <th id="T_9e18c_level0_col4" class="col_heading level0 col4" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e18c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9e18c_row0_col0" class="data row0 col0" >SVM</td>
#       <td id="T_9e18c_row0_col1" class="data row0 col1" >0.930841</td>
#       <td id="T_9e18c_row0_col2" class="data row0 col2" >0.930841</td>
#       <td id="T_9e18c_row0_col3" class="data row0 col3" >0.930841</td>
#       <td id="T_9e18c_row0_col4" class="data row0 col4" >0.930841</td>
#     </tr>
#     <tr>
#       <th id="T_9e18c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9e18c_row1_col0" class="data row1 col0" >Naive_Bayes</td>
#       <td id="T_9e18c_row1_col1" class="data row1 col1" >0.961467</td>
#       <td id="T_9e18c_row1_col2" class="data row1 col2" >0.961467</td>
#       <td id="T_9e18c_row1_col3" class="data row1 col3" >0.961467</td>
#       <td id="T_9e18c_row1_col4" class="data row1 col4" >0.961467</td>
#     </tr>
#     <tr>
#       <th id="T_9e18c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9e18c_row2_col0" class="data row2 col0" >Random Forest</td>
#       <td id="T_9e18c_row2_col1" class="data row2 col1" >0.988354</td>
#       <td id="T_9e18c_row2_col2" class="data row2 col2" >0.988354</td>
#       <td id="T_9e18c_row2_col3" class="data row2 col3" >0.988354</td>
#       <td id="T_9e18c_row2_col4" class="data row2 col4" >0.988354</td>
#     </tr>
#     <tr>
#       <th id="T_9e18c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9e18c_row3_col0" class="data row3 col0" >KNN</td>
#       <td id="T_9e18c_row3_col1" class="data row3 col1" >0.896909</td>
#       <td id="T_9e18c_row3_col2" class="data row3 col2" >0.896909</td>
#       <td id="T_9e18c_row3_col3" class="data row3 col3" >0.896909</td>
#       <td id="T_9e18c_row3_col4" class="data row3 col4" >0.896909</td>
#     </tr>
#   </tbody>
# </table>

# %%
Evaluation2=pd.DataFrame(['SVM'],columns=['Algorithm'])
Evaluation2.loc[0,'Precision']=metrics.precision_score(y_test, y_pred_us, average='micro')
Evaluation2.loc[0,'Recall']=metrics.recall_score(y_test, y_pred_us, average='micro')
Evaluation2.loc[0,'F1 Score']=metrics.f1_score(y_test, y_pred_us, average='micro')
Evaluation2.loc[0,'Accuracy']=metrics.accuracy_score(y_test,y_pred_us)
Evaluation2.loc[1,'Algorithm']='Naive_Bayes'
Evaluation2.loc[1,'Precision']=metrics.precision_score(y_test, y_pred1_us, average='micro')
Evaluation2.loc[1,'Recall']=metrics.recall_score(y_test, y_pred1_us, average='micro')
Evaluation2.loc[1,'F1 Score']=metrics.f1_score(y_test, y_pred1_us, average='micro')
Evaluation2.loc[1,'Accuracy']=metrics.accuracy_score(y_test,y_pred1_us)
Evaluation2.loc[2,'Algorithm']='Random Forest'
Evaluation2.loc[2,'Precision']=metrics.precision_score(y_test, y_pred2_us, average='micro')
Evaluation2.loc[2,'Recall']=metrics.recall_score(y_test, y_pred2_us, average='micro')
Evaluation2.loc[2,'F1 Score']=metrics.f1_score(y_test, y_pred2_us, average='micro')
Evaluation2.loc[2,'Accuracy']=metrics.accuracy_score(y_test,y_pred2_us)
Evaluation2.loc[3,'Algorithm']='KNN'
Evaluation2.loc[3,'Precision']=metrics.precision_score(y_test, y_pred3_us, average='micro')
Evaluation2.loc[3,'Recall']=metrics.recall_score(y_test, y_pred3_us, average='micro')
Evaluation2.loc[3,'F1 Score']=metrics.f1_score(y_test, y_pred3_us, average='micro')
Evaluation2.loc[3,'Accuracy']=metrics.accuracy_score(y_test,y_pred3_us)
print("UnderSampling")
display(Evaluation2.loc[:].style.highlight_max(subset=['Precision', 'Accuracy','Recall','F1 Score'], color='green'))
# Out:
# UnderSampling
# <style type="text/css">
# #T_4bf82_row2_col1, #T_4bf82_row2_col2, #T_4bf82_row2_col3, #T_4bf82_row2_col4 {
#   background-color: green;
# }
# </style>
# <table id="T_4bf82">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4bf82_level0_col0" class="col_heading level0 col0" >Algorithm</th>
#       <th id="T_4bf82_level0_col1" class="col_heading level0 col1" >Precision</th>
#       <th id="T_4bf82_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_4bf82_level0_col3" class="col_heading level0 col3" >F1 Score</th>
#       <th id="T_4bf82_level0_col4" class="col_heading level0 col4" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4bf82_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4bf82_row0_col0" class="data row0 col0" >SVM</td>
#       <td id="T_4bf82_row0_col1" class="data row0 col1" >0.930841</td>
#       <td id="T_4bf82_row0_col2" class="data row0 col2" >0.930841</td>
#       <td id="T_4bf82_row0_col3" class="data row0 col3" >0.930841</td>
#       <td id="T_4bf82_row0_col4" class="data row0 col4" >0.930841</td>
#     </tr>
#     <tr>
#       <th id="T_4bf82_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4bf82_row1_col0" class="data row1 col0" >Naive_Bayes</td>
#       <td id="T_4bf82_row1_col1" class="data row1 col1" >0.966930</td>
#       <td id="T_4bf82_row1_col2" class="data row1 col2" >0.966930</td>
#       <td id="T_4bf82_row1_col3" class="data row1 col3" >0.966930</td>
#       <td id="T_4bf82_row1_col4" class="data row1 col4" >0.966930</td>
#     </tr>
#     <tr>
#       <th id="T_4bf82_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4bf82_row2_col0" class="data row2 col0" >Random Forest</td>
#       <td id="T_4bf82_row2_col1" class="data row2 col1" >0.975270</td>
#       <td id="T_4bf82_row2_col2" class="data row2 col2" >0.975270</td>
#       <td id="T_4bf82_row2_col3" class="data row2 col3" >0.975270</td>
#       <td id="T_4bf82_row2_col4" class="data row2 col4" >0.975270</td>
#     </tr>
#     <tr>
#       <th id="T_4bf82_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4bf82_row3_col0" class="data row3 col0" >KNN</td>
#       <td id="T_4bf82_row3_col1" class="data row3 col1" >0.896909</td>
#       <td id="T_4bf82_row3_col2" class="data row3 col2" >0.896909</td>
#       <td id="T_4bf82_row3_col3" class="data row3 col3" >0.896909</td>
#       <td id="T_4bf82_row3_col4" class="data row3 col4" >0.896909</td>
#     </tr>
#   </tbody>
# </table>

# %%
(X)
# Out:
#               ra        dec         u         g         r         i         z  \
# 0     183.531326   0.089693  19.47406  17.04240  15.94699  15.50342  15.22531
# 1     183.598370   0.135285  18.66280  17.21449  16.67637  16.48922  16.39150
# 2     183.680207   0.126185  19.38298  18.19169  17.47428  17.08732  16.80125
# 3     183.870529   0.049911  17.76536  16.60272  16.16116  15.98233  15.90438
# 4     183.883288   0.102557  17.55025  16.26342  16.43869  16.55492  16.61326
# ...          ...        ...       ...       ...       ...       ...       ...
# 9993  131.398915  51.533706  17.79613  16.02621  15.15955  14.71488  14.33840
# 9995  131.316413  51.539547  18.81777  17.47053  16.91508  16.68305  16.50570
# 9996  131.306083  51.671341  18.27255  17.43849  17.07692  16.71661  16.69897
# 9998  131.477151  51.753068  18.88287  17.91068  17.53152  17.36284  17.13988
# 9999  131.665012  51.805307  19.27586  17.37829  16.30542  15.83548  15.50588
#
#       redshift  plate    mjd  fiberid
# 0    -0.000009   3306  54922      491
# 1    -0.000055    323  51615      541
# 2     0.123111    287  52023      513
# 3    -0.000111   3306  54922      510
# 4     0.000590   3306  54922      512
# ...        ...    ...    ...      ...
# 9993  0.055515    447  51877      249
# 9995  0.027583    447  51877      246
# 9996  0.117772    447  51877      228
# 9998  0.014019    447  51877      229
# 9999  0.118417    447  51877      233
#
# [8693 rows x 11 columns]
